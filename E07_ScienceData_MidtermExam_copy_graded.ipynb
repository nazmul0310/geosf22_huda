# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# # Exercise 7: Science Data - Midterm Take-Home Exam
#
# ### Content & Grading
#
# You will receive the following points for this exercise:
#
# - **A.1**: *50 P* <a href='#pd'> Pandas </a>
# - **B**: *20 P* <a href='#bd'> Batch Download </a>
# - **C**: *20 P* <a href='#nc'> NetCDF4   </a>
#
# Total:
# - 90 points
# - **up to 15 extra credit points for reasonaby commenting your code**
#
# ---
# ### Important considerations for the exam
# - This is a take home exam. The due date will be announced on Canvas (about two weeks time).
# - You can work in a team of up to 2 people on this exam.
# - **If you work in a team, please indicate names of all collaborators above. And make a statement on individual contributions.** (Provide detail, who coded which part, and/or which parts you worked on together, and/or who wrote which part of the summary, etc.)!
# - This is an open book exam. You can use any literature or internet resources. We encourage you to search for helpful built-in functions or functions of the Python standard libraries (e.g. math) on the Python documentation pages (https://docs.python.org/3/) or open source tutorials.
# - If you use external references for your code solutions, please document this with your answers and/or in comments throughout the script file.
# ---

# %% [markdown]
# ### Name and Collaborator
# Add your name and the name of any collaborator in the code cell below.

# %%
Name = 'Nazmul Huda'
Collaborators = ['']

# %% [markdown]
# <div class="alert alert-warning">
#
# **Grades:**
#
# Total points: **105**/90
#
# - Part A (50P)
#     - A1: 20/20
#     - A2: 24/24
#     - A3: 6/6
# - Part B: 20/20
# - Part C: 20/20
# - ExtCrd: 15/15
#
#
# Signed: Susanna Werth
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# **Additional Grading Notes:**
#
# Some more comments might be provided below for answers without full points. If there are no comments, your answer is correct.
#
#
#
#
#
#
#
# </div>

# %% [markdown]
# ---
# ---
# <a id='pd'></a>
# # A. Pandas: Analyze Population Predictions
#
# ### Overview
#
# Code that reads UN population prediction data from file into a Pandas data frame and  anlyze the data, to answer given questions. The results of the data analysis should be summarized in a markdown cell.

# %% [markdown]
# ### Data set
#
# We will analyze future prediction of annual total population for different countries and regions around the world stored in the file **WPP2019_INTHOUSAND.txt**. The file is stored in the folder **./data** of the homework repository (**geosf22_material**).
#
# The data were retrieved from the UN website https://population.un.org/wpp/Download/Standard/Population/.
#
# - We are using the medium variant predictions for "Total Population - Both Sexes" for the years 2020 to 2100.
# - The data are stored in the comma-separated text file WPP2019_INTHOUSANDS.txt
# - Population numbers are given in unit of thousand, hence, a population of 1 in the file stands for 1000 people.
#
# The file contains one header line:
# ```txt
# Region-subregion-country-or-area, 2022, 2023, ..., 2010
# ```
#
# All following lines/rows contain population estimates for countries/region for the years 2020-2100. The first entry in each line indicates name of the country/region and all following entries contain the population number for this region/country and for the year (corresponding to the column indicated in the file header).
#
# For example the second entry indicates population estimate of 11891 (Eleventhousand-and-eighthundredninetyone) for the year 2020.
# ```txt
# Burundi, 11 891,   12 255, ..., 50 904
# ```
#
# Note that the populuation numbers are stored in a way, that there is a space between the third and the fourth digit. Make sure to correctly read the numbers, before analyzing the data.

# %% [markdown]
# ---
# ### A.1 Write functions for importing this dataset
#
# Add your code in the following code cell, to:
#
# - Import neccessary modules or functions.
#
# - Write a function `readUNpopData` that reads the dataset from the file `WPP2019_INTHOUSANDS.txt` into a pandas data frame and returns that data frame at the end of the function run.
#
# - Write a function `selectCountry` that requests user input at the beginning of the program that requests a country of interest to be analyzed later on.
#
# - Add a docstring to all functions.
#
# - Add comments throughout your code to increase readability.
#
# Note: put the code for this tasks in the code cell below, then move on to the next task.

# %%
# ADD YOUR CODE - B.1

import pandas as pd 
import numpy as np

def readUNpopData():
    '''readUNpopData function will allow a text file to be read into a pandas dataframe.
    The data has unncessary spaces in between numeric values and they are removes using for loop.'''
    x = pd.read_csv('../../../TeachingMaterial/data/WPP2019_INTHOUSAND.txt', index_col=None)
    for i in x.columns[1:]:
        x[i] = x[i].str.replace(" ", '').astype(int) #replacing the spaces with nothing
    return x

readUNpopData()


def selectCountry():
    '''selectCountry function will allow users to store a name as a variable.
    It will also show the name stored'''
    x = input("Enter Country Name here: ") # the input is stored as a value which is later confirmed 
    print(f"You entered: {x}")
    return (x)

selectCountry()
# Out:
# Enter Country Name here:  China
# You entered: China
# 'China'

# %% [markdown]
# ---
# ### A.2 Data Analysis
#
# In the code cell below, first use the functions above to actually import the data, and request one country/region name from user input.
#
# Then write code to answer the following questions:
#
# 1. What was the estimated total world population in 2020?
#
# 2. What is the predicted total world population in 2050 and 2100?
#
# 3. What is the population increase of the total world population from now (2020) to 2050 and 2100 (in percentage)?
#
# 4. Which three countries are expected to contain the largest population in 10 years.
#
# 5. For the country/region name received from the user input request, retrieve a subset of the pandas data frame and return the population numbers for 2020, 2050 and 2100 for this country/region.
#
# 6. What is the current population and expected population increase in percentage by 2100 for USA, China, India, Nigeria, Egypt, Brazil, Australia, France, Turkey ? (Code this analysis as a loop over a list of these countries, instead of copying-pasting your code for each country).
#
# 7. Which country is expected to grow the fastest until 2100 (in percentage, relative to their population in 2020).
#
# 8. What is the mean and standard deviation for percentage growth rates for all countries (worldwide) from today until 2100?

# %%
# ADD YOUR CODE - B.2

UNpopData = readUNpopData()  #storing the updated dataset in the variable 'UNpopData'

user_country = selectCountry() ##storing the user selected country in the variable 'country'

UNpopData
# Out:
# Enter Country Name here:  China
# You entered: China
#     Region-subregion-country-or-area    2020    2021    2022    2023    2024  \
# 0                            Burundi   11891   12255   12625   12999   13379
# 1                            Comoros     870     888     907     926     946
# 2                           Djibouti     988    1002    1016    1030    1043
# 3                            Eritrea    3546    3601    3662    3728    3796
# 4                           Ethiopia  114964  117876  120813  123771  126751
# ..                               ...     ...     ...     ...     ...     ...
# 230                          Bermuda      62      62      62      62      62
# 231                           Canada   37742   38068   38388   38704   39017
# 232                        Greenland      57      57      57      57      57
# 233        Saint Pierre and Miquelon       6       6       6       6       6
# ...

# %%
#1. The estimated total world population of 2020 would be the sum of the column '2020'
total_world_pop_2020 = (UNpopData['2020'].sum())*1000
print('A: The estimated total world population of the year 2020: '+ str(total_world_pop_2020))

#2. The predicted total world population of the years 2050 & 2100

total_world_pop_2050 = (UNpopData['2050'].sum())*1000
total_world_pop_2100 = (UNpopData['2100'].sum())*1000

print('B: The predicted total world population of the year 2050 is: '+ str(total_world_pop_2050) + ' & 2100 is: '+ 
      str(total_world_pop_2100))


#3. The percent population increase of the total world population from 2020 to 2050 and 2100

perc_increase_2020_2050 = (UNpopData['2050'].sum() - UNpopData['2020'].sum())/(UNpopData['2020'].sum())*100
perc_increase_2020_2100 = (UNpopData['2100'].sum() - UNpopData['2020'].sum())/(UNpopData['2020'].sum())*100

print('C: The percent population increase of the total world population from 2020 to 2050 is: ' + 
      str(round(perc_increase_2020_2050,2))+'% & from 2020 to 2100 is: ' + str(round(perc_increase_2020_2100,2))+'%')

#4. Three countries that are expected to contain the largest population in 10 years.

top3countries_2030 = UNpopData.nlargest(3,'2030')['Region-subregion-country-or-area'].values.tolist()

print('D. Countries w/ largest population in 2030: ' +  str(top3countries_2030))


# 5. For the country/region name received from the user input request, 
# retrieve a subset of the pandas data frame 
# and return the population numbers for 2020, 2050 and 2100 for this country/region.

userrequest = UNpopData[UNpopData['Region-subregion-country-or-area'] == user_country]

print('E. Population for 2020, 2050 and 2100 for ' + str(user_country) + ' is ' + 
      np.array_str(userrequest['2020'].values*1000)+', ' + str(userrequest['2050'].values*1000)+', '+ 
      str(userrequest['2100'].values*1000))


# 6. What is the current population and expected population increase in percentage by 2100 for 
# USA, China, India, Nigeria, Egypt, Brazil, Australia, France, Turkey ? 
# (Code this analysis as a loop over a list of these countries, instead of copying-pasting your code for each country).

list_countries = ['United States of America', 'China', 'India', 'Nigeria', 'Egypt', 'Brazil', 'Australia', 'France', 'Turkey']

for i in list_countries:
    j=UNpopData[UNpopData['Region-subregion-country-or-area']==i]
    perc_change_loop = (((j['2100']-j['2020'])/j['2020']).values*100)
    print('Percent change for ' + i)
    print(perc_change_loop)


# 7. Which country is expected to grow the fastest until 2100 (in percentage, relative to their population in 2020).


UNpopData['perc_chnage_4m_2020_2_2100'] = (UNpopData['2100'] - UNpopData['2020']) / UNpopData['2020'] * 100
UNpopData

print('Country with highest population growth is ' + 
      str(UNpopData.nlargest(1,'perc_chnage_4m_2020_2_2100')['Region-subregion-country-or-area'].values.tolist()) + 
      ' and the percent value is: '+   
      str(UNpopData.nlargest(1,'perc_chnage_4m_2020_2_2100')['perc_chnage_4m_2020_2_2100'].values.tolist()))


# What is the mean and standard deviation for percentage growth rates for all countries (worldwide) from today until 2100?

UNpopData['perc_chnage_4m_2022_2_2100'] = (UNpopData['2100'] - UNpopData['2022']) / UNpopData['2022'] * 100

#code modified due to the question asking today which is (2022)

mean  = UNpopData['perc_chnage_4m_2022_2_2100'].mean()

print('Mean value of percent change for all countries/regions: ' + str(round(mean,2)))

stan_dev  = UNpopData['perc_chnage_4m_2022_2_2100'].std()

print('Standard deviation of percent change for all countries/regions: ' + str(round(stan_dev,2)))
# Out:
# A: The estimated total world population of the year 2020: 7794803000
# B: The predicted total world population of the year 2050 is: 9735031000 & 2100 is: 10875389000
# C: The percent population increase of the total world population from 2020 to 2050 is: 24.89% & from 2020 to 2100 is: 39.52%
# D. Countries w/ largest population in 2030: ['India', 'China', 'United States of America']
# E. Population for 2020, 2050 and 2100 for China is [1439324000], [1402405000], [1064993000]
# Percent change for United States of America
# [31.07252804]
# Percent change for China
# [-26.00741737]
# Percent change for India
# [4.85665259]
# Percent change for Nigeria
# [255.55544775]
# Percent change for Egypt
# [119.60931851]
# Percent change for Brazil
# [-14.99630691]
# Percent change for Australia
# [68.14509804]
# Percent change for France
# [0.3431688]
# Percent change for Turkey
# [2.17100037]
# Country with highest population growth is ['Niger'] and the percent value is: [581.4020737803115]
# ...

# %% [markdown]
# ---
# ### A.3 Summary
#
# In the markdown cell below, provide a reasonable summery for all the data analysis questions.

# %% [markdown]
# ### ---
#
# **ADD YOUR ANSWERS FOR A.3 IN THIS MARKDOWN CELL !!!**
#
# The data analysis above have given many elements of thought regarding the population trend over the next 80 years. Estimated population of 2020 is 7.79 billion and the predicted population in 30 years, in 2050 is 9.73 billion. Approximate jump of 2 billion people in less than 30 years. The total population prediction for 2100 is 10.88 billion and comparing with 2050 it is not as steep as of a change comparing with prior 30 years. That means the population growth is predicted to be slowed down. It is also evident from a few countries' data where the growth even declines to negative, resulting less population in coming days. This is also evident with the percent change values calculated for two different time windows, 1. 2020 ~ 2050 & 2. 2020 ~ 2100. Almost 25% change in the next 30 years and in next 80 years the change is around 40%.
#
# The analysis also shows which countries will have the highest number of population in coming days. In 8 years, India China and Unites States of America will have the highest number of population. This information will be helpful to make different policies and changes to existing ones to proper utilize population resources. Also, China although still a country with huge number of population is seeming to be slowing down around the end of this century. With the global change trend, analysing the data for individual country gives the perspective of where one country stand comparing with the rest of the world. USA seems to be on par with the global chnage trend as the the change will be 31% increase and the global average is 40%. Australia si also having a similar growth but more than the USA. Australia also invites a lot of immigrants and that might be a factor for their growth. China, as mentioned earlier is slowing down rapidly and the population will be 25% less than what it is now, this suggests that China has many ongoing measure to prevent their population growth problem. India, France, Turkey all will see moderate to no change in population rise. For a country like India, 4% growth is a very low number as the past trent used to be muich steeper. Brazil, also a country with large population is also reucing the population by 15%. Nigeria is facing one of the worst population growth problems as it will be facing a 255% increase and it is often seen in the countries of Africa. Egypy will be doubling up in population. Worst of all, Niger will see a rise in population of 6 times more than what the population currently is.
#
# Lastly, the average of change in individual countries summed up, shows a different value which is pretty close to the calculated global change together. The average of individual countries suggest all the countries on average facing 50% growth but we have also seen that the major contributor to the world population, China, Brazil, India are all slowing down. That means the countries with lower population now will increase in numbers in coming years. The standard deviation suggests that 67% countries will see change of 0% rise to 100% and that is normal according to the data.
#
# ### ---

# %% [markdown]
# <div class="alert alert-warning">
#
# **Additional Grading Notes:**
#
# Excellent summary!
#
#
#
#
#
#
#
# </div>

# %% [markdown]
# ---
# <a id='bd'></a>
# # B. Batch Download
#
# ### Overview
# Often it is necessary to download multiple file with the same name, except for a running number or date. For example imagine to download a time series of global maps, where each sample in time is stored in a separate file. If you have do download daily data for a year, that would already make 365 files. In this case it would be best to do a batch download, hence, write a loop, that automatically generates all neded file names and downloads them one by one.
#
# Here we will perform an example batch download of ~10 files.

# %% [markdown]
# ### Data
# Source: http://test.opendap.org/opendap/hyrax/data/ff/
#
# This server provides multiple test files named `testN.dat`, with N running from 0 to 11. But file #5 and #6 are missing.

# %% [markdown]
# ### Task:
#
# 1) Write code to batch download all the test files in a loop from 0-11 (for all files) and from the website provided above, store them in a separate folder, e.g., `./out`. First, write the batch download only, then expand your code  with the next task.
#
# 2) Include a missing-file error handling, for missing files in the batch, without assuming you know, which files are missing. For that, a code example is provided below, it makes use of the following features:
#
#     - function raise_for_status(): returns an HTTPError object if an error has occurred during the download process, e.g., if the file does not exist.
#
#     - try/except: these statements are an example for an exception-handling. The except-sequence will be executed if the try-sequence raises any error, otherwise the except-sequence is skipped. This is not a loop and a try/except sequence alone will be performed only once.
#
#     - then combine the try/except error handling with the batch download, to check for the HTTPError for every download

# %%
# We know that 1-11 exists but we don't know if there is any missing values or not 

number_list = list(range(0, 12, 1))

import requests

for i in number_list:
    try:
        r = requests.get('http://test.opendap.org/opendap/hyrax/data/ff/test' + str(i)+'.dat')
        r.raise_for_status() #it checks if the file exists or not, if it fails it skips to except and doesn't create the file
        open('./out/test' +str(i)+'.dat', "wb").write(r.content)
        print('Successfully downloaded test' + str(i)+'.dat')
    except:
        print('Download failed for test' + str(i)+'.dat')
# Out:
# Successfully downloaded test0.dat
# Successfully downloaded test1.dat
# Successfully downloaded test2.dat
# Successfully downloaded test3.dat
# Successfully downloaded test4.dat
# Download failed for test5.dat
# Download failed for test6.dat
# Successfully downloaded test7.dat
# Successfully downloaded test8.dat
# Successfully downloaded test9.dat
# Successfully downloaded test10.dat
# Successfully downloaded test11.dat

# %% [markdown]
# ---
# <a id='nc'></a>
# # C. NetCDF4
#
# ### Overview
# Download and read a netCDF file, calculate a map statistic and plot the result.
#
# ### Tasks
#
# Download the netCDF file `tos_O1_2001-2002.nc` from the server https://www.unidata.ucar.edu/software/netcdf/examples/tos_O1_2001-2002.nc. Then read the data from the file and calculate the maximum sea surface temperature during the year 2001 for each gridpoint. Then print the resulting map. For guidance and to receive full points, follow these next steps:
#
# * Import the package `Dataset` from the module netCDF4 (1 point)
# * Read the netcdf dataset from the file `tos_O1_2001-2002.nc` and save the content to the variable `data` (1 point)
# * Print out the information of the data set to get an overview
# * Assign the data content to the variable `lat`, `lon`, `time`, `tos`. Consider to select the correct object from the masked arrays, if needed (extract the data object). (2 points)
# * Close the netCDF dataset/file (1 point)
# * Convert the 1D lat/lon arrays to a meshgrid arrays and save them to the variables `lat_grid` and `lon_grid` (2 points)
# * Converting missing values in '`tos` data to `np.nan` (convert to Celsius or leave at Kelvin, as you prefer) (1 point)
# * Use vectorized code with the function `np.amax()` (allows to set an axis) to retrieve the maximum sea surface temperature during the year 2001 for each data pixel and save the results in a new map `tos_max2001` (6 points)
# * Make a simple plot the new map `tos_max` with labeled coordinate axes and a colorbar with the colormap `'viridis'`. No further labeling needed (1 point)

# %%
### YOUR CODE HERE

import requests

from netCDF4 import Dataset 

# 2. Define the URL & filename for the file to download
filename = 'tos_O1_2001-2002.nc'
url = 'https://www.unidata.ucar.edu/software/netcdf/examples/' + filename

# 3. Use requests.get() to download the data behind that URL
response = requests.get(url, allow_redirects=True, stream=True)  # better for large files

#optional: print out the content type at the url-address
print(response.headers.get('content-type'))   

# 4. Write the file to a new BINARY file on your computer
f=open(filename, "wb")
f.write(response.content)
f.close()
# Out:
# application/x-netcdf

# %%
data = Dataset('../../../TeachingMaterial/data/tos_O1_2001-2002.nc')

print(data)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     title: IPSL  model output prepared for IPCC Fourth Assessment SRES A2 experiment
#     institution: IPSL (Institut Pierre Simon Laplace, Paris, France)
#     source: IPSL-CM4_v1 (2003) : atmosphere : LMDZ (IPSL-CM4_IPCC, 96x71x19) ; ocean ORCA2 (ipsl_cm4_v1_8, 2x2L31); sea ice LIM (ipsl_cm4_v
#     contact: Sebastien Denvil, sebastien.denvil@ipsl.jussieu.fr
#     project_id: IPCC Fourth Assessment
#     table_id: Table O1 (13 November 2004)
#     experiment_id: SRES A2 experiment
#     realization: 1
#     cmor_version: 0.96
#     Conventions: CF-1.0
#     history: YYYY/MM/JJ: data generated; YYYY/MM/JJ+1 data transformed  At 16:37:23 on 01/11/2005, CMOR rewrote data to comply with CF standards and IPCC Fourth Assessment requirements
#     references: Dufresne et al, Journal of Climate, 2015, vol XX, p 136
#     comment: Test drive
# ...

# %%
#Assigning the data content to the variable lat, lon, time, tos

lat = data.variables['lat'][:].data
lon = data.variables['lon'][:].data
time = data.variables['time'][:].data
tos_data = data.variables['tos'][:].data
tos_mask = data.variables['tos'][:].mask

# %%
data.close()

# %% [markdown]
# Use vectorized code with the function np.amax() (allows to set an axis) to retrieve the maximum sea surface temperature during the year 2001 for each data pixel and save the results in a new map tos_max2001 (6 points)
#
# Make a simple plot the new map tos_max with labeled coordinate axes and a colorbar with the colormap 'viridis'. No further labeling needed (1 point)

# %%
import numpy as np
import matplotlib.pyplot as plt

# converting the 1D coordinate arrays to a meshgrid
lon_grid, lat_grid = np.meshgrid(lon,lat)

# %%
# converting missing values in 'tos' data to np.nan and converted to celsius
tos_data[tos_data==1e20] = np.nan
tos_data = tos_data -273.15

# %%
tos_data2001 = tos_data[0:12,:,:] #filtering only the year 2001
tos_max2001 = np.amax(tos_data2001,axis = 0) # We are looking for max value only in axis 1
tos_max2001
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [-1.7039795, -1.7036133, -1.7032166, ..., -1.7046814, -1.7045898,
#         -1.7043762],
#        [-1.6926575, -1.6925049, -1.6923828, ..., -1.6931458, -1.6929626,
#         -1.69281  ],
#        [-1.6834412, -1.6833801, -1.6833191, ..., -1.6836243, -1.6835632,
#         -1.6835022]], dtype=float32)

# %%
# plotting the first 'tos' map (after replacing missing values with nan)
plt.pcolormesh(lon,lat, tos_max2001, shading='auto', cmap='viridis') 

# adding a colorbar
cbar = plt.colorbar()

# adding labels
cbar.set_label('degree Celsius')
plt.title("Sea Surface Temperature, Jan/2001")
# Out:
# Text(0.5, 1.0, 'Sea Surface Temperature, Jan/2001')
